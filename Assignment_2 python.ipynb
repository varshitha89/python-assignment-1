# %%
a=input("enter a value")
b=input("enter b value")
c=int(a)+int(b)
print(c)
# Out:
# enter a value20
# enter b value25
# 45

# %%
name=input("enter name")
print("happy",name)
# Out:
# enter nameworld
# happy world

# %%
hours=float(input('enter hours:'))
rate=float(input('enter rate:'))
pay=hours*rate
print(pay)
# Out:
# enter hours:30
# enter rate:4
# 120.0

# %%
width=17
height=12.0
a=width//2
b=width//20
c=height/3
d=1+2*5
print(a)
print(b)
print(c)
print(d)
print(type(a))
print(type(b))
print(type(c))
print(type(c))
print(type(d))
# Out:
# 8
# 0
# 4.0
# 11
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'int'>

# %%
celsius=float(input('enter degree in celsius:'))
fah=float(celsius*915+32)
print("degree celsius into fah  is",fah)
# Out:
# enter degree in celsius:110
# degree celsius into fah  is 100682.0
